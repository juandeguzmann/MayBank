# %%
import websocket
import logging
import datetime
import json

from backend.models.finnhub import LivePrice

logging.basicConfig(level=logging.INFO, format="%(asctime)s %(message)s")
logging.getLogger("websocket").setLevel(logging.WARNING) 
logger = logging.getLogger(__name__)

# %%
def on_message(ws, message):
    data = json.loads(message)
    if data.get("type") == "trade":
        latest = max(data["data"], key=lambda t: t["t"])
        logger.info(LivePrice(
            conditions=latest["c"],
            price=latest["p"],
            symbol=latest["s"],
            timestamp=latest["t"],
            volume=latest["v"],
        ))


def on_error(ws, error):
    logger.error(error)

def on_close(ws, close_status_code, close_msg):
    pass

def on_open(ws):
    ws.send('{"type":"subscribe","symbol":"AAPL"}')
    ws.send('{"type":"subscribe","symbol":"BINANCE:BTCUSDT"}')

if __name__ == "__main__":
    ws = websocket.WebSocketApp("wss://ws.finnhub.io?token=d7tgsthr01qugn0ailf0d7tgsthr01qugn0ailfg",
                              on_message=on_message,
                              on_error=on_error,
                              on_close=on_close)
    ws.on_open = on_open
    ws.run_forever()
# Out:
# 2026-05-06 11:40:53,925 conditions=None price=Decimal('82259.28') symbol='BINANCE:BTCUSDT' timestamp=datetime.datetime(2026, 5, 6, 10, 40, 52, 801000, tzinfo=datetime.timezone.utc) volume=Decimal('0.00042')
# 2026-05-06 11:40:54,912 conditions=None price=Decimal('82259.29') symbol='BINANCE:BTCUSDT' timestamp=datetime.datetime(2026, 5, 6, 10, 40, 54, 19000, tzinfo=datetime.timezone.utc) volume=Decimal('0.00058')
# 2026-05-06 11:40:55,973 conditions=None price=Decimal('82259.29') symbol='BINANCE:BTCUSDT' timestamp=datetime.datetime(2026, 5, 6, 10, 40, 55, 378000, tzinfo=datetime.timezone.utc) volume=Decimal('0.00222')
# 2026-05-06 11:40:56,913 conditions=None price=Decimal('82259.28') symbol='BINANCE:BTCUSDT' timestamp=datetime.datetime(2026, 5, 6, 10, 40, 56, 532000, tzinfo=datetime.timezone.utc) volume=Decimal('0.00044')
# 2026-05-06 11:40:57,919 conditions=None price=Decimal('82259.29') symbol='BINANCE:BTCUSDT' timestamp=datetime.datetime(2026, 5, 6, 10, 40, 57, 370000, tzinfo=datetime.timezone.utc) volume=Decimal('0.00002')
# 2026-05-06 11:40:59,966 conditions=None price=Decimal('82259.28') symbol='BINANCE:BTCUSDT' timestamp=datetime.datetime(2026, 5, 6, 10, 40, 59, 456000, tzinfo=datetime.timezone.utc) volume=Decimal('0.00008')
# 2026-05-06 11:41:00,991 conditions=None price=Decimal('82259.29') symbol='BINANCE:BTCUSDT' timestamp=datetime.datetime(2026, 5, 6, 10, 41, 0, 234000, tzinfo=datetime.timezone.utc) volume=Decimal('0.00007')
# 2026-05-06 11:41:00,992 conditions=None price=Decimal('82260') symbol='BINANCE:BTCUSDT' timestamp=datetime.datetime(2026, 5, 6, 10, 41, 0, 244000, tzinfo=datetime.timezone.utc) volume=Decimal('0.00012')
# 2026-05-06 11:41:01,921 conditions=None price=Decimal('82259.99') symbol='BINANCE:BTCUSDT' timestamp=datetime.datetime(2026, 5, 6, 10, 41, 1, 596000, tzinfo=datetime.timezone.utc) volume=Decimal('0.00049')
# 2026-05-06 11:41:02,938 conditions=None price=Decimal('82268.94') symbol='BINANCE:BTCUSDT' timestamp=datetime.datetime(2026, 5, 6, 10, 41, 2, 480000, tzinfo=datetime.timezone.utc) volume=Decimal('0.00165')
# 2026-05-06 11:41:02,939 conditions=None price=Decimal('82268.94') symbol='BINANCE:BTCUSDT' timestamp=datetime.datetime(2026, 5, 6, 10, 41, 2, 660000, tzinfo=datetime.timezone.utc) volume=Decimal('0.0012')
# 2026-05-06 11:41:03,926 conditions=None price=Decimal('82268.93') symbol='BINANCE:BTCUSDT' timestamp=datetime.datetime(2026, 5, 6, 10, 41, 2, 958000, tzinfo=datetime.timezone.utc) volume=Decimal('0.01362')
# 2026-05-06 11:41:03,928 conditions=None price=Decimal('82268.93') symbol='BINANCE:BTCUSDT' timestamp=datetime.datetime(2026, 5, 6, 10, 41, 3, 166000, tzinfo=datetime.timezone.utc) volume=Decimal('0.00239')
# 2026-05-06 11:41:04,935 conditions=None price=Decimal('82268.94') symbol='BINANCE:BTCUSDT' timestamp=datetime.datetime(2026, 5, 6, 10, 41, 4, 623000, tzinfo=datetime.timezone.utc) volume=Decimal('0.00012')
# 2026-05-06 11:41:05,946 conditions=None price=Decimal('82268.92') symbol='BINANCE:BTCUSDT' timestamp=datetime.datetime(2026, 5, 6, 10, 41, 5, 168000, tzinfo=datetime.timezone.utc) volume=Decimal('0.00029')
# 2026-05-06 11:41:07,033 conditions=None price=Decimal('82268.93') symbol='BINANCE:BTCUSDT' timestamp=datetime.datetime(2026, 5, 6, 10, 41, 6, 24000, tzinfo=datetime.timezone.utc) volume=Decimal('0.0005')
# 2026-05-06 11:41:07,256
